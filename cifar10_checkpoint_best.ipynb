# %%
from sklearn.preprocessing import LabelBinarizer
from pyimagesearch.nn.conv import MiniVGGNet
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
args = {
    'weights' : 'weights/best/cifar10_best_weights.hdf5'
}

# %%
# load the training and testing data, then scale it into the
# range [0, 1]
print("[INFO] loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float") / 255.0
testX = testX.astype("float") / 255.0

# convert the labels from integers to vectors
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)
# Out:
# [INFO] loading CIFAR-10 data...
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 8s 0us/step

# %%
# initialize the optimizer and model
print("[INFO] compiling model...")
opt = SGD(lr=0.01, decay=0.01 / 40, momentum=0.9, nesterov=True)
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=10)
model.compile(loss="categorical_crossentropy", optimizer=opt,
metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
# construct the callback to save only the best model to the disk based on validation loss
checkpoint = ModelCheckpoint(args['weights'], monitor='val_loss', save_best_only=True, verbose=1)
callbacks = [checkpoint]

# %%
# train the network
print("[INFO] training network...")
H = model.fit(trainX, trainY, validation_data=(testX, testY),
batch_size=64, epochs=40, callbacks=callbacks, verbose=2)
# Out:
# [INFO] training network...
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/40
#
# Epoch 00001: val_loss improved from inf to 1.20116, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 73s - loss: 1.6207 - accuracy: 0.4550 - val_loss: 1.2012 - val_accuracy: 0.5751
# Epoch 2/40
#
# Epoch 00002: val_loss improved from 1.20116 to 0.96027, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 1.1681 - accuracy: 0.5908 - val_loss: 0.9603 - val_accuracy: 0.6557
# Epoch 3/40
#
# Epoch 00003: val_loss improved from 0.96027 to 0.88577, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.9904 - accuracy: 0.6534 - val_loss: 0.8858 - val_accuracy: 0.6894
# Epoch 4/40
#
# Epoch 00004: val_loss improved from 0.88577 to 0.80593, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.8798 - accuracy: 0.6905 - val_loss: 0.8059 - val_accuracy: 0.7152
# Epoch 5/40
#
# Epoch 00005: val_loss did not improve from 0.80593
# 50000/50000 - 15s - loss: 0.8093 - accuracy: 0.7157 - val_loss: 0.8305 - val_accuracy: 0.7076
# Epoch 6/40
#
# Epoch 00006: val_loss improved from 0.80593 to 0.69587, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.7451 - accuracy: 0.7396 - val_loss: 0.6959 - val_accuracy: 0.7597
# Epoch 7/40
#
# Epoch 00007: val_loss did not improve from 0.69587
# 50000/50000 - 15s - loss: 0.6988 - accuracy: 0.7541 - val_loss: 0.7630 - val_accuracy: 0.7403
# Epoch 8/40
#
# Epoch 00008: val_loss improved from 0.69587 to 0.69238, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.6651 - accuracy: 0.7667 - val_loss: 0.6924 - val_accuracy: 0.7651
# Epoch 9/40
#
# Epoch 00009: val_loss improved from 0.69238 to 0.64432, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.6260 - accuracy: 0.7800 - val_loss: 0.6443 - val_accuracy: 0.7748
# Epoch 10/40
#
# Epoch 00010: val_loss did not improve from 0.64432
# 50000/50000 - 15s - loss: 0.6010 - accuracy: 0.7873 - val_loss: 0.6762 - val_accuracy: 0.7672
# Epoch 11/40
#
# Epoch 00011: val_loss improved from 0.64432 to 0.62679, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.5682 - accuracy: 0.7998 - val_loss: 0.6268 - val_accuracy: 0.7856
# Epoch 12/40
#
# Epoch 00012: val_loss improved from 0.62679 to 0.61801, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.5472 - accuracy: 0.8048 - val_loss: 0.6180 - val_accuracy: 0.7883
# Epoch 13/40
#
# Epoch 00013: val_loss improved from 0.61801 to 0.59396, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.5227 - accuracy: 0.8151 - val_loss: 0.5940 - val_accuracy: 0.7971
# Epoch 14/40
#
# Epoch 00014: val_loss improved from 0.59396 to 0.57794, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.5083 - accuracy: 0.8195 - val_loss: 0.5779 - val_accuracy: 0.8018
# Epoch 15/40
#
# Epoch 00015: val_loss improved from 0.57794 to 0.57351, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.4891 - accuracy: 0.8260 - val_loss: 0.5735 - val_accuracy: 0.8069
# Epoch 16/40
#
# Epoch 00016: val_loss did not improve from 0.57351
# 50000/50000 - 15s - loss: 0.4755 - accuracy: 0.8307 - val_loss: 0.5788 - val_accuracy: 0.8066
# Epoch 17/40
#
# Epoch 00017: val_loss did not improve from 0.57351
# 50000/50000 - 15s - loss: 0.4541 - accuracy: 0.8392 - val_loss: 0.5893 - val_accuracy: 0.8017
# Epoch 18/40
#
# Epoch 00018: val_loss did not improve from 0.57351
# 50000/50000 - 15s - loss: 0.4412 - accuracy: 0.8433 - val_loss: 0.5965 - val_accuracy: 0.7975
# Epoch 19/40
#
# Epoch 00019: val_loss improved from 0.57351 to 0.56988, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.4295 - accuracy: 0.8457 - val_loss: 0.5699 - val_accuracy: 0.8046
# Epoch 20/40
#
# Epoch 00020: val_loss improved from 0.56988 to 0.56505, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.4190 - accuracy: 0.8493 - val_loss: 0.5651 - val_accuracy: 0.8084
# Epoch 21/40
#
# Epoch 00021: val_loss did not improve from 0.56505
# 50000/50000 - 15s - loss: 0.4017 - accuracy: 0.8575 - val_loss: 0.5866 - val_accuracy: 0.8062
# Epoch 22/40
#
# Epoch 00022: val_loss did not improve from 0.56505
# 50000/50000 - 15s - loss: 0.3889 - accuracy: 0.8639 - val_loss: 0.5749 - val_accuracy: 0.8079
# Epoch 23/40
#
# Epoch 00023: val_loss did not improve from 0.56505
# 50000/50000 - 15s - loss: 0.3812 - accuracy: 0.8657 - val_loss: 0.5845 - val_accuracy: 0.8078
# Epoch 24/40
#
# Epoch 00024: val_loss did not improve from 0.56505
# 50000/50000 - 15s - loss: 0.3718 - accuracy: 0.8666 - val_loss: 0.5663 - val_accuracy: 0.8130
# Epoch 25/40
#
# Epoch 00025: val_loss improved from 0.56505 to 0.55748, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.3626 - accuracy: 0.8694 - val_loss: 0.5575 - val_accuracy: 0.8132
# Epoch 26/40
#
# Epoch 00026: val_loss did not improve from 0.55748
# 50000/50000 - 15s - loss: 0.3547 - accuracy: 0.8731 - val_loss: 0.5616 - val_accuracy: 0.8170
# Epoch 27/40
#
# Epoch 00027: val_loss did not improve from 0.55748
# 50000/50000 - 15s - loss: 0.3409 - accuracy: 0.8773 - val_loss: 0.5694 - val_accuracy: 0.8150
# Epoch 28/40
#
# Epoch 00028: val_loss did not improve from 0.55748
# 50000/50000 - 15s - loss: 0.3338 - accuracy: 0.8800 - val_loss: 0.5728 - val_accuracy: 0.8170
# Epoch 29/40
#
# Epoch 00029: val_loss did not improve from 0.55748
# 50000/50000 - 15s - loss: 0.3252 - accuracy: 0.8840 - val_loss: 0.5659 - val_accuracy: 0.8197
# Epoch 30/40
#
# Epoch 00030: val_loss did not improve from 0.55748
# 50000/50000 - 15s - loss: 0.3231 - accuracy: 0.8829 - val_loss: 0.5611 - val_accuracy: 0.8170
# Epoch 31/40
#
# Epoch 00031: val_loss did not improve from 0.55748
# 50000/50000 - 15s - loss: 0.3112 - accuracy: 0.8899 - val_loss: 0.5953 - val_accuracy: 0.8118
# Epoch 32/40
#
# Epoch 00032: val_loss improved from 0.55748 to 0.55640, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.3058 - accuracy: 0.8904 - val_loss: 0.5564 - val_accuracy: 0.8198
# Epoch 33/40
#
# Epoch 00033: val_loss did not improve from 0.55640
# 50000/50000 - 15s - loss: 0.3016 - accuracy: 0.8912 - val_loss: 0.5923 - val_accuracy: 0.8120
# Epoch 34/40
#
# Epoch 00034: val_loss did not improve from 0.55640
# 50000/50000 - 15s - loss: 0.2988 - accuracy: 0.8931 - val_loss: 0.5571 - val_accuracy: 0.8250
# Epoch 35/40
#
# Epoch 00035: val_loss did not improve from 0.55640
# 50000/50000 - 15s - loss: 0.2922 - accuracy: 0.8959 - val_loss: 0.5655 - val_accuracy: 0.8199
# Epoch 36/40
#
# Epoch 00036: val_loss did not improve from 0.55640
# 50000/50000 - 15s - loss: 0.2840 - accuracy: 0.8981 - val_loss: 0.5734 - val_accuracy: 0.8177
# Epoch 37/40
#
# Epoch 00037: val_loss improved from 0.55640 to 0.55368, saving model to weights/best/cifar10_best_weights.hdf5
# 50000/50000 - 15s - loss: 0.2805 - accuracy: 0.9003 - val_loss: 0.5537 - val_accuracy: 0.8228
# Epoch 38/40
#
# Epoch 00038: val_loss did not improve from 0.55368
# 50000/50000 - 15s - loss: 0.2741 - accuracy: 0.9018 - val_loss: 0.5557 - val_accuracy: 0.8244
# Epoch 39/40
#
# Epoch 00039: val_loss did not improve from 0.55368
# 50000/50000 - 15s - loss: 0.2694 - accuracy: 0.9038 - val_loss: 0.5668 - val_accuracy: 0.8248
# Epoch 40/40
#
# Epoch 00040: val_loss did not improve from 0.55368
# 50000/50000 - 15s - loss: 0.2633 - accuracy: 0.9059 - val_loss: 0.5579 - val_accuracy: 0.8236
